# %%
import pandas as pd
import numpy as np
taxi_data = pd.read_csv('./data/dataset/train_taxi_tims.csv', encoding='euc-kr')
taxi_data = taxi_data[taxi_data['승차X좌표'] != 0.0]

# %%
taxi_data.columns
# Out:
# Index(['차량번호', '승차시간', '승차X좌표', '승차Y좌표', '요일'], dtype='object')

# %%
taxi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1082657 entries, 44 to 1089448
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   차량번호    1082657 non-null  object
#  1   승차시간    1082657 non-null  object
#  2   승차X좌표   1082657 non-null  float64
#  3   승차Y좌표   1082657 non-null  float64
#  4   요일      1082657 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 49.6+ MB

# %%
taxi_data.drop('차량번호', axis=1, inplace=True)

# %%
columns = {
    '승차시간' : 'brdTime',
    '승차X좌표' : 'brdXCrd',
    '승차Y좌표' : 'brdYCrd',
    '요일' : 'week'}

# %%
taxi_data.rename(columns=columns, inplace=True)

# %%
taxi_data=taxi_data.reset_index(drop=True)

# %%
taxi_data.head()
# Out:
#                brdTime     brdXCrd    brdYCrd      week
# 0  2023-04-01 05:15:37  127.377749  36.350133  Saturday
# 1  2023-04-01 05:42:47  127.358606  36.353338  Saturday
# 2  2023-04-01 06:02:58  127.380240  36.365618  Saturday
# 3  2023-04-01 06:15:05  127.426666  36.351172  Saturday
# 4  2023-04-01 06:28:36  127.408217  36.324442  Saturday

# %%
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
# %matplotlib inline


# ===== 데이터 로드 ==============================================================
taxi_data = pd.read_csv('./data/dataset/train_taxi_tims.csv', encoding='euc-kr')

# 데이터 결측값 삭제 =========================================================
taxi_data = taxi_data[taxi_data['승차X좌표'] != 0.0]
taxi_data.drop

# 데이터 범주화(월, 계절, 시간) ================================================
columns = {
    'month': '

taxi_data['

# 날씨 데이터 로드 ===========================================================

# 공휴일 데이터 로드 ==========================================================

# 데이터 원핫인코딩 ===========================================================

# 데이터 시각화(선택) =========================================================

# 모델 생성 =================================================================

# 모델 학습 =================================================================

# 테스트 데이터 전처리 =========================================================

# 테스트 데이터로 예측 =========================================================

# 예측 결과 대조 =============================================================

# 예측 정확도 측정 ============================================================

















# 일 분리: int type
# taxi_data['일'] = taxi_data['승차시간'].apply(lambda x: int(x[8:10]))
# 시각 분리: int type
taxi_data['시각'] = taxi_data['승차시간'].apply(lambda x: int(x[11:13]+x[14:16]+x[17:])) # int 적용?
# 요일 원핫인코딩
day_encoding = pd.get_dummies(taxi_data['요일'])
day_encoding = day_encoding.astype(int)
taxi_data = taxi_data.drop('요일', axis=1)
taxi_data = taxi_data.join(day_encoding)
taxi_data = taxi_data.drop(['승차시간', '차량번호'], axis=1)


# 학습, 테스트 데이터 분리
X = taxi_data[taxi_data.columns.difference(['승차X좌표', '승차Y좌표'])]
y = taxi_data[['승차X좌표', '승차Y좌표']]
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=42)

# 랜덤 포레스트 모델 학습
model = RandomForestRegressor(random_state=42)
model.fit(train_X, train_y)

# 모델 평가
test_y_pred = model.predict(test_X)
mse = mean_squared_error(test_y, test_y_pred)
rmse = np.sqrt(mse)
print(f'RMSE: {rmse}')
print("Train_R2:", model.score(train_X, train_y))
print("Test_R2:", model.score(test_X, test_y))

# 그래프
test_y_pred = pd.DataFrame(test_y_pred, columns=['예측승차X좌표', '예측승차Y좌표'])
