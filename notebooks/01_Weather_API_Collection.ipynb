# %%
import requests

url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst'
params ={'serviceKey' : '',
         'pageNo' : '1',
         'numOfRows' : '10',
         'dataType' : 'XML',
         'base_date' : '20210628',
         'base_time' : '0600',
         'nx' : '55',
         'ny' : '127' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response><header><resultCode>10</resultCode><resultMsg>\xec\xb5\x9c\xea\xb7\xbc 3\xec\x9d\xbc \xea\xb0\x84\xec\x9d\x98 \xec\x9e\x90\xeb\xa3\x8c\xeb\xa7\x8c \xec\xa0\x9c\xea\xb3\xb5\xed\x95\xa9\xeb\x8b\x88\xeb\x8b\xa4.</resultMsg></header></response>\r\n'
